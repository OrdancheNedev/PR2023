# %%
import numpy as np
import pandas as pd
import warnings
import matplotlib.pyplot as plt
# %matplotlib inline
warnings.filterwarnings("ignore")
proekt = pd.read_csv('foreveralone.csv')

# %% [markdown]
# # Exploratory data analysis

# %%
proekt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 469 entries, 0 to 468
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   time                   469 non-null    object
#  1   gender                 469 non-null    object
#  2   sexuallity             469 non-null    object
#  3   age                    469 non-null    int64
#  4   income                 469 non-null    object
#  5   race                   469 non-null    object
#  6   bodyweight             469 non-null    object
#  7   virgin                 469 non-null    object
#  8   prostitution_legal     469 non-null    object
#  9   pay_for_sex            469 non-null    object
#  10  friends                469 non-null    float64
#  11  social_fear            469 non-null    object
#  12  depressed              469 non-null    object
#  13  what_help_from_others  469 non-null    object
# ...

# %%
proekt.shape
# Out:
# (469, 19)

# %%
proekt.isnull().sum()
# Out:
# time                      0
# gender                    0
# sexuallity                0
# age                       0
# income                    0
# race                      0
# bodyweight                0
# virgin                    0
# prostitution_legal        0
# pay_for_sex               0
# friends                   0
# social_fear               0
# depressed                 0
# what_help_from_others     0
# attempt_suicide           0
# employment                0
# job_title                12
# edu_level                 0
# improve_yourself_how      0
# dtype: int64

# %%
proekt.head(10)
# Out:
#                  time  gender   sexuallity  age              income  \
# 0  5/17/2016 20:04:18    Male     Straight   35  $30,000 to $39,999
# 1  5/17/2016 20:04:30    Male     Bisexual   21       $1 to $10,000
# 2  5/17/2016 20:04:58    Male     Straight   22                  $0
# 3  5/17/2016 20:08:01    Male     Straight   19       $1 to $10,000
# 4  5/17/2016 20:08:04    Male     Straight   23  $30,000 to $39,999
# 5  5/17/2016 20:09:09    Male     Straight   24  $50,000 to $74,999
# 6  5/17/2016 20:10:56    Male     Straight   22       $1 to $10,000
# 7  5/17/2016 20:11:13  Female  Gay/Lesbian   24  $20,000 to $29,999
# 8  5/17/2016 20:11:52    Male     Straight   20  $10,000 to $19,999
# 9  5/17/2016 20:13:37    Male     Straight   33  $50,000 to $74,999
#
#                  race     bodyweight virgin prostitution_legal  \
# 0  White non-Hispanic  Normal weight    Yes                 No
# 1  White non-Hispanic    Underweight    Yes                 No
# ...

# %%
import seaborn as sns
sns.heatmap(proekt.isnull(),yticklabels=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
proekt.dropna(inplace=True)

# %%
sns.heatmap(proekt.isnull(),yticklabels=False,cbar='False')
# Out:
# <AxesSubplot:>

# %%
proekt.isnull().sum()
# Out:
# time                     0
# gender                   0
# sexuallity               0
# age                      0
# income                   0
# race                     0
# bodyweight               0
# virgin                   0
# prostitution_legal       0
# pay_for_sex              0
# friends                  0
# social_fear              0
# depressed                0
# what_help_from_others    0
# attempt_suicide          0
# employment               0
# job_title                0
# edu_level                0
# improve_yourself_how     0
# dtype: int64

# %%
proekt['time'].nunique()
# Out:
# 456

# %%
proekt['gender'].unique()
# Out:
# array(['Male', 'Female', 'Transgender male', 'Transgender female'],
#       dtype=object)

# %%
proekt['sexuallity'].unique()
# Out:
# array(['Straight', 'Bisexual', 'Gay/Lesbian'], dtype=object)

# %%
proekt['age'].unique()
# Out:
# array([35, 21, 22, 19, 23, 24, 20, 33, 32, 25, 29, 17, 28, 26, 18, 55, 16,
#        38, 45, 30, 15, 34, 70, 12, 36, 31, 27, 57, 44, 41, 37, 39, 48, 42],
#       dtype=int64)

# %%
proekt['income'].unique()
# Out:
# array(['$30,000 to $39,999', '$1 to $10,000', '$0', '$50,000 to $74,999',
#        '$20,000 to $29,999', '$10,000 to $19,999', '$75,000 to $99,999',
#        '$150,000 to $174,999', '$125,000 to $149,999',
#        '$100,000 to $124,999', '$174,999 to $199,999',
#        '$40,000 to $49,999', '$200,000 or more'], dtype=object)

# %%
proekt['race'].unique()
# Out:
# array(['White non-Hispanic', 'Hispanic (of any race)', 'Asian',
#        'white and asian', 'caucasian', 'Black', 'Middle Eastern',
#        'half Arab', 'Pakistani', 'helicopterkin', 'Turkish', 'Indian',
#        'Native american', 'Mixed', 'mixed', 'Mixed white/asian', 'indian',
#        'Multi', 'Native American mix', 'North African',
#        'White and Native American',
#        'First two answers. Gender is androgyne, not male; sexuality is asexual, not bi.',
#        'European'], dtype=object)

# %%
proekt['bodyweight'].unique()
# Out:
# array(['Normal weight', 'Underweight', 'Overweight', 'Obese'],
#       dtype=object)

# %%
proekt['virgin'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
proekt['prostitution_legal'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
proekt['pay_for_sex'].unique()
# Out:
# array(['No', 'Yes and I have', "Yes but I haven't"], dtype=object)

# %%
proekt['friends'].unique()
# Out:
# array([0.0e+00, 1.0e+01, 8.0e+00, 2.0e+00, 6.0e+00, 5.0e+00, 2.0e+01,
#        1.0e+00, 1.2e+01, 4.0e+01, 3.0e+00, 1.3e+01, 1.5e+01, 1.7e+01,
#        4.0e+00, 7.0e+00, 9.0e+00, 3.0e+01, 1.0e+02, 1.6e+01, 1.8e+01,
#        8.0e+01, 2.8e+01, 2.5e+01, 6.0e+01, 6.0e+02, 2.0e-01, 4.0e+02,
#        1.1e+01, 5.0e-01])

# %%
proekt['social_fear'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
proekt['depressed'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
proekt['what_help_from_others'].nunique()
# Out:
# 50

# %%
proekt['attempt_suicide'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
proekt['employment'].nunique()
# Out:
# 9

# %%
proekt['job_title'].nunique()
# Out:
# 275

# %%
proekt['edu_level'].nunique()
# Out:
# 9

# %%
proekt['improve_yourself_how'].nunique()
# Out:
# 61

# %%
proekt['age'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
print("Prosechna vozrast",proekt['age'].mean())
print("Medijana na vozrast",proekt['age'].median())
print("Moda na vozrast",proekt['age'].mode()[0])
# Out:
# Prosechna vozrast 24.032822757111596
# Medijana na vozrast 23.0
# Moda na vozrast 23

# %%
sns.countplot(x='social_fear',data=proekt)
# Out:
# <AxesSubplot:xlabel='social_fear', ylabel='count'>

# %%
sns.countplot(x='sexuallity',data=proekt)
# Out:
# <AxesSubplot:xlabel='sexuallity', ylabel='count'>

# %%
sns.countplot(x='attempt_suicide',data=proekt)
# Out:
# <AxesSubplot:xlabel='attempt_suicide', ylabel='count'>

# %%
sns.countplot(x='depressed',data=proekt)
# Out:
# <AxesSubplot:xlabel='depressed', ylabel='count'>

# %%
sns.countplot(y='edu_level',data=proekt)
# Out:
# <AxesSubplot:xlabel='count', ylabel='edu_level'>

# %%
sns.countplot(y='friends',data=proekt)
# Out:
# <AxesSubplot:xlabel='count', ylabel='friends'>

# %%
sns.countplot(y ='virgin',data=proekt)
# Out:
# <AxesSubplot:xlabel='count', ylabel='virgin'>

# %%
sns.countplot(y='pay_for_sex',data=proekt)
# Out:
# <AxesSubplot:xlabel='count', ylabel='pay_for_sex'>

# %%
sns.countplot(y='income',data=proekt)
# Out:
# <AxesSubplot:xlabel='count', ylabel='income'>

# %%
sns.countplot(y='bodyweight',data=proekt)
# Out:
# <AxesSubplot:xlabel='count', ylabel='bodyweight'>

# %%
sns.countplot(y='race',data=proekt)
# Out:
# <AxesSubplot:xlabel='count', ylabel='race'>

# %%
sns.countplot(y='employment',data=proekt)
# Out:
# <AxesSubplot:xlabel='count', ylabel='employment'>

# %%
proekt.drop(proekt[proekt['friends']>15].index,inplace=True)
proekt.drop(proekt[proekt['age']>35].index,inplace=True)
proekt['friends'].replace([0.2,0.5,15],[0,0,13],inplace=True)
proekt['friends'] = proekt['friends'].astype(int)

# %%
sns.countplot(y='friends',data=proekt)
# Out:
# <AxesSubplot:xlabel='count', ylabel='friends'>

# %%
proekt.drop(['time','what_help_from_others','job_title','improve_yourself_how','prostitution_legal','race','income'],axis=1,inplace=True)
proekt.head(5)
# Out:
#   gender sexuallity  age     bodyweight virgin     pay_for_sex  friends  \
# 0   Male   Straight   35  Normal weight    Yes              No        0
# 1   Male   Bisexual   21    Underweight    Yes              No        0
# 2   Male   Straight   22     Overweight    Yes              No       10
# 3   Male   Straight   19     Overweight    Yes              No        8
# 4   Male   Straight   23     Overweight     No  Yes and I have       10
#
#   social_fear depressed attempt_suicide  \
# 0         Yes       Yes             Yes
# 1         Yes       Yes              No
# 2         Yes       Yes              No
# 3         Yes       Yes              No
# 4          No       Yes              No
#
#                                        employment  \
# 0                              Employed for wages
# 1                Out of work and looking for work
# 2  Out of work but not currently looking for work
# 3                                       A student
# ...

# %%
boxplot = proekt.boxplot()

# %%
sns.countplot(x='friends',hue='social_fear',data=proekt)
# Out:
# <AxesSubplot:xlabel='friends', ylabel='count'>

# %%
sns.countplot(x='friends',hue='depressed',data=proekt)
# Out:
# <AxesSubplot:xlabel='friends', ylabel='count'>

# %%
sns.countplot(x='depressed',hue='social_fear',data=proekt)
# Out:
# <AxesSubplot:xlabel='depressed', ylabel='count'>

# %%
sns.countplot(x='sexuallity',hue='depressed',data=proekt)
# Out:
# <AxesSubplot:xlabel='sexuallity', ylabel='count'>

# %%
sns.countplot(x='gender',hue='depressed',data=proekt)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
sns.countplot(x='social_fear',hue='pay_for_sex',data=proekt)
# Out:
# <AxesSubplot:xlabel='social_fear', ylabel='count'>

# %%
sns.countplot(x='depressed',hue='pay_for_sex',data=proekt)
# Out:
# <AxesSubplot:xlabel='depressed', ylabel='count'>

# %%
sns.countplot(y='employment',hue='depressed',data=proekt)
# Out:
# <AxesSubplot:xlabel='count', ylabel='employment'>

# %%
sns.countplot(y='employment',hue='social_fear',data=proekt)
# Out:
# <AxesSubplot:xlabel='count', ylabel='employment'>

# %%
sns.countplot(y='virgin',hue='depressed',data=proekt)
# Out:
# <AxesSubplot:xlabel='count', ylabel='virgin'>

# %%
sns.countplot(y='virgin',hue='social_fear',data=proekt)
# Out:
# <AxesSubplot:xlabel='count', ylabel='virgin'>

# %%
sns.countplot(y='bodyweight',hue='social_fear',data=proekt)
# Out:
# <AxesSubplot:xlabel='count', ylabel='bodyweight'>

# %%
sns.countplot(y='bodyweight',hue='depressed',data=proekt)
# Out:
# <AxesSubplot:xlabel='count', ylabel='bodyweight'>

# %%
proekt['sexuallity'].replace(['Straight','Gay/Lesbian','Bisexual'],[0,1,1],inplace=True)
proekt['gender'].replace(['Male','Female','Transgender male','Transgender female'],[0,0,1,1],inplace=True)
proekt['social_fear'].replace(['Yes','No'],[1,0],inplace=True)
proekt['depressed'].replace(['Yes','No'],[1,0],inplace=True)
proekt['attempt_suicide'].replace(['Yes','No'],[1,0],inplace=True)
proekt['edu_level'].replace(["High school graduate, diploma or the equivalent (for example: GED)",'Trade/technical/vocational training','Some college, no degree','Some high school, no diploma','Associate degree','Professional degree',"Bachelor’s degree","Master’s degree",'Doctorate degree'],[0,0,0,0,1,1,1,1,1],inplace=True)

# %%
proekt.drop(['bodyweight','pay_for_sex','virgin','employment'],axis=1,inplace=True)
proekt.head()
# Out:
#    gender  sexuallity  age  friends  social_fear  depressed  attempt_suicide  \
# 0       0           0   35        0            1          1                1
# 1       0           1   21        0            1          1                0
# 2       0           0   22       10            1          1                0
# 3       0           0   19        8            1          1                0
# 4       0           0   23       10            0          1                0
#
#    edu_level
# 0          1
# 1          0
# 2          0
# 3          0
# 4          0

# %%
sns.countplot(x='sexuallity',data=proekt)
# Out:
# <AxesSubplot:xlabel='sexuallity', ylabel='count'>

# %%
sns.countplot(x='gender',data=proekt)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
sns.countplot(x='social_fear',data=proekt)
# Out:
# <AxesSubplot:xlabel='social_fear', ylabel='count'>

# %% [markdown]
# # LogisticRegression

# %%
X = proekt.drop("attempt_suicide",axis=1)
y = proekt['attempt_suicide']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
log = LogisticRegression(max_iter=200)

# %%
log.fit(X_train,y_train)
# Out:
# LogisticRegression(max_iter=200)

# %%
y_pred = log.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.91       100
#            1       0.57      0.19      0.29        21
#
#     accuracy                           0.83       121
#    macro avg       0.71      0.58      0.60       121
# weighted avg       0.80      0.83      0.80       121

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, jaccard_score

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[97,  3],
#        [17,  4]], dtype=int64)

# %%
accuracy_score(y_test,y_pred)*100
# Out:
# 83.47107438016529

# %%
jaccard_score(y_test,y_pred)*100
# Out:
# 16.666666666666664

# %% [markdown]
# # Naive Bayes Classifier

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model = GaussianNB()

# %%
model_obj = model.fit(X_train,y_train)

# %%
y_out = model.predict(X_test)

# %%
print('Training Accuracy: ',model.score(X_train,y_train))
# Out:
# Training Accuracy:  0.7892857142857143

# %%
print('Test Accuracy: ',model.score(X_test,y_test))
# Out:
# Test Accuracy:  0.8347107438016529

# %%
print(classification_report(y_test,y_out))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.92      0.90       100
#            1       0.53      0.43      0.47        21
#
#     accuracy                           0.83       121
#    macro avg       0.71      0.67      0.69       121
# weighted avg       0.82      0.83      0.83       121

# %%
confusion_matrix(y_test,y_out)
# Out:
# array([[92,  8],
#        [12,  9]], dtype=int64)

# %%
jaccard_score(y_test,y_out)*100
# Out:
# 31.03448275862069

# %% [markdown]
# # KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
out = knn.predict(X_test)

# %%
print(confusion_matrix(y_test,out))
# Out:
# [[81 19]
#  [16  5]]

# %%
print(classification_report(y_test,out))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.81      0.82       100
#            1       0.21      0.24      0.22        21
#
#     accuracy                           0.71       121
#    macro avg       0.52      0.52      0.52       121
# weighted avg       0.73      0.71      0.72       121

# %%
error_rate = []
for i in range(1,40):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,y_train)
    pred_i = knn.predict(X_test)
    error_rate.append(np.mean(pred_i!=y_test))

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,40),error_rate,color='blue',linestyle='dashed',marker='o',markerfacecolor='red',markersize=10)
plt.title("Error Rate vs K Value")
plt.xlabel("K")
plt.ylabel("Error Rate")
# Out:
# Text(0, 0.5, 'Error Rate')

# %%
knn = KNeighborsClassifier(n_neighbors=4)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %%
out = knn.predict(X_test)

# %%
accuracy_score(y_test,out)*100
# Out:
# 84.29752066115702

# %%
jaccard_score(y_test,out)*100
# Out:
# 9.523809523809524

# %%
print(confusion_matrix(y_test,out))
# Out:
# [[100   0]
#  [ 19   2]]

# %%
print(classification_report(y_test,out))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      1.00      0.91       100
#            1       1.00      0.10      0.17        21
#
#     accuracy                           0.84       121
#    macro avg       0.92      0.55      0.54       121
# weighted avg       0.87      0.84      0.78       121

# %% [markdown]
# # XGBoost Classifier

# %%
#!pip install xgboost
from xgboost import XGBClassifier

# %%
x_model = XGBClassifier(use_label_encoder=False,eval_metric='mlogloss')

# %%
x_model.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, gamma=None, gpu_id=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=None, ...)

# %%
xgb_pred = x_model.predict(X_test)

# %%
confusion_matrix(y_test,xgb_pred)
# Out:
# array([[86, 14],
#        [14,  7]], dtype=int64)

# %%
accuracy_score(y_test,xgb_pred)*100
# Out:
# 76.85950413223141

# %%
jaccard_score(y_test,xgb_pred)*100
# Out:
# 20.0

# %%
print(classification_report(y_test,xgb_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86       100
#            1       0.33      0.33      0.33        21
#
#     accuracy                           0.77       121
#    macro avg       0.60      0.60      0.60       121
# weighted avg       0.77      0.77      0.77       121

# %% [markdown]
# # Visualisation of results

# %%
def plot_roc(roc_auc):
    plt.figure(figsize=(7,7))
    plt.title('Receiver Operating Characteristic')
    plt.plot(false_positive_rate,true_positive_rate,color='red', label ='AUC = %0.2f' % roc_auc)
    plt.legend(loc = 'lower right')
    plt.plot([0, 1],[0, 1],linestyle='--')
    plt.axis('tight')
    plt.ylabel('True positive rate')
    plt.xlabel('Fale positive rate')

# %%
from sklearn.metrics import roc_curve, auc

# %% [markdown]
# # Roc Curve for Logistic Regression

# %%
false_positive_rate, true_positive_rate, threshold = roc_curve(y_test,y_pred)

# %%
roc_auc_log = auc(false_positive_rate,true_positive_rate)

# %%
roc_auc_log
# Out:
# 0.5802380952380952

# %%
plot_roc(roc_auc_log)

# %% [markdown]
# # Roc Curve for Naive Bayes Classifier

# %%
false_positive_rate, true_positive_rate, threshold = roc_curve(y_test,y_out)

# %%
roc_auc_nb = auc(false_positive_rate,true_positive_rate)
roc_auc_nb
# Out:
# 0.6742857142857143

# %%
plot_roc(roc_auc_nb)

# %% [markdown]
# # Roc Curve for KNN Classifier

# %%
false_positive_rate, true_positive_rate, threshold = roc_curve(y_test,out)

# %%
roc_auc_knn = auc(false_positive_rate,true_positive_rate)
roc_auc_knn
# Out:
# 0.5476190476190477

# %%
plot_roc(roc_auc_knn)

# %% [markdown]
# # Roc Curve for XGBoost Classifier

# %%
false_positive_rate, true_positive_rate, threshold = roc_curve(y_test,xgb_pred)

# %%
roc_auc_xgb = auc(false_positive_rate,true_positive_rate)
roc_auc_xgb
# Out:
# 0.5966666666666666

# %%
plot_roc(roc_auc_xgb)

# %% [markdown]
# # KMeans

# %%
newdata = X.iloc[:,2:4]

# %%
newdata
# Out:
#      age  friends
# 0     35        0
# 1     21        0
# 2     22       10
# 3     19        8
# 4     23       10
# ..   ...      ...
# 462   18        6
# 463   12        0
# 464   26       10
# 465   31       10
# 468   28        3
#
# [401 rows x 2 columns]

# %%
from sklearn.cluster import KMeans
import seaborn as sns
sns.set()

# %%
kmeans = KMeans(n_clusters=5)

# %%
kmeans.fit(newdata)
# Out:
# KMeans(n_clusters=5)

# %%
kmeans.cluster_centers_
# Out:
# array([[24.37931034,  2.35344828],
#        [19.89565217,  1.07826087],
#        [25.45652174, 10.63043478],
#        [30.5       ,  2.61666667],
#        [18.859375  ,  7.046875  ]])

# %%
print(kmeans.labels_)
# Out:
# [3 1 2 4 2 0 1 2 1 3 3 0 0 1 0 3 2 4 3 2 4 4 4 4 0 4 3 1 0 4 2 0 0 2 2 4 3
#  0 1 0 4 0 4 3 0 0 0 0 3 0 1 1 1 0 1 4 4 1 3 1 2 0 0 0 2 1 0 0 1 3 0 4 0 3
#  4 3 4 3 3 0 3 0 0 2 1 4 4 1 0 4 0 3 3 0 4 1 0 1 1 2 1 1 1 1 0 4 1 1 1 3 1
#  3 0 4 3 4 3 0 3 4 3 1 1 4 3 4 0 4 4 0 3 3 1 1 1 0 0 1 4 1 2 0 1 4 0 2 3 3
#  1 1 0 2 2 0 2 2 3 3 0 0 0 1 0 3 4 0 1 1 0 3 0 0 1 0 0 0 3 4 0 1 2 3 4 4 3
#  1 2 3 2 1 3 3 1 0 4 0 1 4 1 0 3 4 0 3 0 1 0 0 0 1 0 0 4 0 2 1 1 4 3 0 2 1
#  1 1 0 1 0 2 0 0 0 0 3 0 3 0 2 0 2 0 1 4 1 0 0 3 2 1 1 4 1 1 2 3 3 1 0 2 1
#  0 1 4 3 4 1 4 4 2 1 0 1 4 1 0 3 2 1 0 1 0 4 0 3 0 0 1 4 2 4 1 4 0 0 4 1 0
#  1 4 2 1 1 0 1 0 1 1 0 3 2 1 4 4 3 4 1 3 1 1 3 2 4 3 1 1 0 4 1 1 1 1 1 2 2
#  1 4 2 0 3 1 1 1 1 1 0 1 4 4 0 0 4 0 4 3 0 0 1 1 3 1 1 1 1 0 0 1 0 0 1 2 1
#  0 1 0 1 0 1 0 2 1 0 1 1 0 0 0 0 2 0 2 0 1 1 2 2 3 4 4 1 2 2 3]

# %%
print(type(kmeans.labels_))
unique, counts = np.unique(kmeans.labels_,return_counts=True)
print(dict(zip(unique,counts)))
# Out:
# <class 'numpy.ndarray'>
# {0: 116, 1: 115, 2: 46, 3: 60, 4: 64}

# %%
newdata['cluster']=kmeans.labels_
sns.set_style('whitegrid')
sns.lmplot('age','friends',data=newdata,hue='cluster',
          palette='coolwarm',size=6,aspect=1,fit_reg=False)

# %% [markdown]
# # Користени трудови:
#
# 1. Број на самоубиства и методи кај различни возрасни групи: Австралиски податоци и перцепции, Џон Сноудон, 1997
# 2. Предвидувања со Машинско учење на самоубиствени идеи, планирање и обиди помеѓу млади Корејци: Популациско-базирана студија, Џеонгјун Ли, Тијунг Пак, 2022
